# %%
while True:
    try:
        a = int(input("Введите целое число: "))
    except:
        print("Вы ввели не целое число, ошибка")
        continue
    break
if (a<=2):
  y = a*a+4*a+5
  print("f(a)", y)
else:
  y = 1/(a*a+4*a+5)
  print("f(a)", y)
# Out:
# Введите целое число: 6
# f(a) 0.015384615384615385
