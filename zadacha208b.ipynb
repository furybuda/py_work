# %%
import math 
n = int(input("Введите натурально число:  "))
i = int
max = 1
s = 0
for i in range (1,n+1):
  if (i > max) and (i % 2 == 1):
    max = i
  if (i % 2 == 0):
    s = s + 1
print( "Максимальное нечетное число:  ", max)
print(s,"Кол-во четных чисел")
# Out:
# Введите натурально число:  5
# Максимальное нечетное число:   5
# 2 Кол-во четных чисел
