# %%
! pip install pandas
import tensorflow as tf

tf.test.gpu_device_name()

batch_size = 128
num_classes = 10
эпох  =  12

from math import fabs

a = input()
b = input()
c = (int(a)+int(b))/2
v = fabs(int(a)*int(b))/2
info = "Среднее арифметическое: " + str(c) + "  Среднее геометрическое: " + str(v)
print (info)
# Out:
# ...
# 6
# 12
# Среднее арифметическое: 9.0Среднее геометрическое: 36.0
